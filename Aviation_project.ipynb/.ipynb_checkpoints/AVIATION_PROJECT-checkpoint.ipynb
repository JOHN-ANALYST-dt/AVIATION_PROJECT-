# %% [markdown]
# <center><h1><b>AVIATION PROJECT</b></h1></center>

# %% [markdown]
# <center><h2><b>Flight Plan for Success: Identifying Low-Risk Aircraft for Commercial Expansion</b></h2></center>

# %% [markdown]
# <h2>1-Business Understanding</h2>

# %% [markdown]
# <h3>In my Business understanding face project, am highly interested in identifying the low Risks aircraft for commercial Expansion pegged on the following objectives</h3>
#
# <h4><b><u>Objectives of the project Analysis</u></b></h4>
# <h4>1-Determining the market Demand</h4>
# Begin by analyzing the current market demand for aviation services<break>.
# Identify the needs,taste and the preferences of potential customers
#
# <h4>2-Safety Risks</h4>
# Which aircraft model have the lowest historical incidents of accidents and safety related groundings
#
# <h4>3-Financial Risks</h4>
# Fuel efficiency (cost per flight hour/mile), typical depreciation rates, resale market liquidity, insurance costs, and typical financing terms.
#
# <h4>4-Operational Reliability</h4>
# Maintenance frequency and average cost per flight hour, dispatch reliability, common component failure rates, availability of spare parts, and complexity of pilot/crew training.
#
# we need also to check at which ai
#
# <h4>5- Market and Regulatory Risk</h4>
# Which aircraft have stable and abundance part supply chains, readily available qualified pilots
#
# <h4>6-Learn about Technological Advancements</h4>
# The Aviation industry is constatly evolving with advancement in technology and inovation solutions

# %% [markdown]
# <h2><b></b>2-Data Understanding</h2></h2>
# The Data Understanding phase is the crucial next step in any data-driven project. It's where you dive deep into the available data to become intimately familiar with its characteristics, quality, and potential relevance to the business problem you're trying to solve

# %% [markdown]
# <h3>Python  library importation</h3>
# We begin by importing our python libraries

# %%
#import the neccesary python libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>File importation</h3>
# we have a csv file from the kaggle named (<b>Aviation Accident Database & Synopses, up to 2023</b>)<br>file path is <i>AviationData.csv</i>

# %%
#import the file using pandas
#display the first 5 rows for us to see what is in the data
Aviation=pd.read_csv("AviationData.csv" ,encoding="latin-1", low_memory=False)
State=pd.read_csv("USState_Codes.csv" ,encoding="latin-1", low_memory=False)

# %% [markdown]
# <h3>Print out the first 5 row data for data check out  </h3>

# %%
Aviation.head(5)
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %% [markdown]
# <h3>print out the last 5 row data for check out </h3>

# %%
#use tail() to print out the last 5 row data
Aviation.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 88884  Annapolis, MD  United States      NaN       NaN          NaN
# 88885    Hampton, NH  United States      NaN       NaN          NaN
# 88886     Payson, AZ  United States  341525N  1112021W          PAN
# 88887     Morgan, UT  United States      NaN       NaN          NaN
# 88888     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 88884          NaN  ...          Personal                 NaN
# ...

# %% [markdown]
# <h3>We need to check out the data information of the data types </h3>

# %%
#we need to check out what kind of the data types we have in out data
Aviation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %% [markdown]
# <h3>Find out the shape of Aviation Data</h3>

# %%
#Aviation shape in rows and colmuns 
Aviation.shape
# Out:
# (88889, 31)

# %% [markdown]
# <h3>Renaming the Event.Date to Date_time</h3>

# %%
#rename the Event.Date to Date-time
Aviation.rename(columns={'Event.Date': 'Date_time'}, inplace=True)

# %% [markdown]
# <h3>Finding out the <b>sum percentage</b> of  Null values in rows and columns</h3>

# %%
total_rows=len(Aviation)
Missing_values=Aviation.isna().sum()*100/total_rows
print(Missing_values)
# Out:
# Event.Id                   0.000000
# Investigation.Type         0.000000
# Accident.Number            0.000000
# Date_time                  0.000000
# Location                   0.058500
# Country                    0.254250
# Latitude                  61.320298
# Longitude                 61.330423
# Airport.Code              43.601570
# Airport.Name              40.708074
# Injury.Severity            1.124999
# Aircraft.damage            3.593246
# Aircraft.Category         63.677170
# Registration.Number        1.554748
# Make                       0.070875
# Model                      0.103500
# Amateur.Built              0.114750
# Number.of.Engines          6.844491
# Engine.Type                7.982990
# FAR.Description           63.974170
# Schedule                  85.845268
# Purpose.of.flight          6.965991
# Air.carrier               81.271023
# Total.Fatal.Injuries      12.826109
# Total.Serious.Injuries    14.073732
# Total.Minor.Injuries      13.424608
# ...

# %% [markdown]
# <h3>From the percentage check, null percentages above 50% will be removed or dropped </h3>

# %%
Aviation.drop(columns=["Air.carrier","Schedule","FAR.Description","Airport.Name","Airport.Code","Report.Status","Latitude","Longitude","Aircraft.Category","Amateur.Built"],inplace=True)

# %% [markdown]
# <h3>Find the shape after dropping the unwanted Columns</h3>

# %%
#find the shape
Aviation.shape
# Out:
# (88889, 21)

# %% [markdown]
# <h3>lets find out the new  mising Values for futher cleaning </h3>

# %%
#missing values in percentages
total=len(Aviation)
Missing_values=Aviation.isna().sum()*100/total
print(Missing_values)
# Out:
# Event.Id                   0.000000
# Investigation.Type         0.000000
# Accident.Number            0.000000
# Date_time                  0.000000
# Location                   0.058500
# Country                    0.254250
# Injury.Severity            1.124999
# Aircraft.damage            3.593246
# Registration.Number        1.554748
# Make                       0.070875
# Model                      0.103500
# Number.of.Engines          6.844491
# Engine.Type                7.982990
# Purpose.of.flight          6.965991
# Total.Fatal.Injuries      12.826109
# Total.Serious.Injuries    14.073732
# Total.Minor.Injuries      13.424608
# Total.Uninjured            6.650992
# Weather.Condition          5.053494
# Broad.phase.of.flight     30.560587
# Publication.Date          15.492356
# dtype: float64

# %% [markdown]
# <h3>We need to check for the Duplicates in our Data</h3>

# %%
#lets check for the duplicates from our Data
Aviation.duplicated().value_counts()
# Out:
# False    88889
# Name: count, dtype: int64

# %% [markdown]
# <h3>Since there are no duplicates, we move to cleaning the NaN values</h3>

# %% [markdown]
# <h3>Lets begin by Filling the gaps </h3>

# %%
#print out the datatypes to see which fomulae to use in cleaning 
Aviation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Date_time               88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Registration.Number     87507 non-null  object
#  9   Make                    88826 non-null  object
#  10  Model                   88797 non-null  object
#  11  Number.of.Engines       82805 non-null  float64
#  12  Engine.Type             81793 non-null  object
#  13  Purpose.of.flight       82697 non-null  object
# ...

# %% [markdown]
# <h3>We will Begin with filling the object datatypes, string with Mode</h3>

# %%
#using the for loop we will fill all the string datatypes with mode 
for col in Aviation.select_dtypes(include='object').columns:
    if Aviation[col].isnull().any():
        mode_val = Aviation[col].mode()[0]
        Aviation[col].fillna(mode_val, inplace=True)

# %% [markdown]
# <h3>Fill all the intergers or float with meadian</h3>

# %% [markdown]
# <h4>Median is the best choice because it is likely to influence the distribution of the data set overall<br>
#     <br>Why This Approach is Effective for Float Data:<br>
#     <br>
# Preserves Distribution<br>
#     <br>:
# Median maintains the central tendency without being affected by extreme value<br>s.
#
# Handles Skewed D
# <br>
# <br>ata:
# For income, age, or sensor readings where distributions are often skewed, median is more representative than <br>m<br>ean.
#
# Computationally Eff
# <br>icient:
# Much faster than complex imputation methods</h4>

# %%
#filling in the float with meadian
for col in Aviation.select_dtypes(include='float64').columns:
    if Aviation[col].isnull().any():
        median_val = Aviation[col].median()
        Aviation[col].fillna(median_val, inplace=True)

# %% [markdown]
# <h3>After finding and and filling in the missing data , we need to check at the percentage of the missing values once more </h3>

# %%
total=len(Aviation)
Aviation.isna().sum()*100/total
# Out:
# Event.Id                  0.0
# Investigation.Type        0.0
# Accident.Number           0.0
# Date_time                 0.0
# Location                  0.0
# Country                   0.0
# Injury.Severity           0.0
# Aircraft.damage           0.0
# Registration.Number       0.0
# Make                      0.0
# Model                     0.0
# Number.of.Engines         0.0
# Engine.Type               0.0
# Purpose.of.flight         0.0
# Total.Fatal.Injuries      0.0
# Total.Serious.Injuries    0.0
# Total.Minor.Injuries      0.0
# Total.Uninjured           0.0
# Weather.Condition         0.0
# Broad.phase.of.flight     0.0
# Publication.Date          0.0
# dtype: float64

# %%
#Aviation[["Model","Make","Broad.phase.of.flight","Total.Uninjured","Publication.Date"]].head(30)

# %% [markdown]
# <h3>Give out the Data description</h3>

# %%
Aviation.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       88889.000000          88889.000000            88889.000000
# mean            1.136552              0.564761                0.240491
# std             0.432545              5.126649                1.434614
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          88889.000000     88889.000000
# mean               0.309127         5.037755
# std                2.083715        26.990914
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %% [markdown]
# <center><h2>3. Exploratory Data Analysis</h2></center>

# %% [markdown]
# <h3>Finding out the outliers in the data set</h3>

# %%
sns.boxplot(x='Weather.Condition', y='Total.Fatal.Injuries', data=Aviation)
plt.title("Fatal Injuries by Weather")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h3>Checking on the Weather condition counts </h3>

# %%
sns.countplot(x='Weather.Condition', data=Aviation)
plt.title("Weather Condition Counts")
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# <h3>From the weather condition acounts Visual Meteorological Conditions was the top in counts.<br> This is a proof that the weather is very faurable for flights</h3>

# %% [markdown]
# <center><h2>Safety Risks</h2></center>

# %% [markdown]
# <h3>Plotting the Aircraft Make with the highest and Lowest incidence of Accidence</h3>

# %%
Count_numb_Accident=Aviation["Make"].value_counts().head()
print(Count_numb_Accident)
# Out:
# Make
# Cessna    22290
# Piper     12029
# CESSNA     4922
# Beech      4330
# PIPER      2841
# Name: count, dtype: int64

# %%
# Step 1: Count the number of accidents per Make
make_counts = Aviation["Make"].value_counts().head(5)

# Step 2: Get the Make with the highest and lowest accident count
highest_make = make_counts.idxmax()
highest_count = make_counts.max()

lowest_make = make_counts[make_counts == make_counts.min()].index[0]
lowest_count = make_counts.min()

# Step 3: Prepare data for plotting
summary = pd.Series({highest_make: highest_count, lowest_make: lowest_count})

# Step 4: Plot
summary.plot(kind='bar', color=['skyblue', 'steelblue'], figsize=(8, 5))

plt.title('Aircraft Make with Highest and Lowest Number of Accidents')
plt.ylabel('Number of Accidents')
plt.xlabel('Aircraft Make')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#plot out the columns of analysis
Aviation[["Make","Total.Fatal.Injuries","Total.Serious.Injuries","Injury.Severity","Aircraft.damage","Total.Uninjured","Number.of.Engines","Country"]].head(20)
# Out:
#                  Make  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0             Stinson                   2.0                     0.0
# 1               Piper                   4.0                     0.0
# 2              Cessna                   3.0                     0.0
# 3            Rockwell                   2.0                     0.0
# 4              Cessna                   1.0                     2.0
# 5   Mcdonnell Douglas                   0.0                     0.0
# 6              Cessna                   4.0                     0.0
# 7              Cessna                   0.0                     0.0
# 8              Cessna                   0.0                     0.0
# 9      North American                   0.0                     0.0
# 10              Piper                   0.0                     0.0
# 11              Beech                   0.0                     0.0
# 12           Bellanca                   0.0                     0.0
# ...

# %% [markdown]
# <h3>Air craft Make and the number of Engine</h3>

# %%
avg_engines_per_make = Aviation.groupby('Make')['Number.of.Engines'].mean().sort_values(ascending=False)

# (Optional) limit to top 10 for clearer plot
avg_engines_top10 = avg_engines_per_make.head(20)

# Plot
plt.figure(figsize=(12, 6))
avg_engines_top10.plot(kind='barh', color='skyblue')

plt.title('Average Number of Engines per Aircraft Make')
plt.ylabel('Aircraft Make')
plt.xlabel('Average Number of Engines')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <H3>plotting between Make and Aircraft Damaged</H3>

# %%
plt.barh(Aviation["Make"].head(100),Aviation["Total.Fatal.Injuries"].head(100))
plt.title(" Make Vs Fatal Injuries")
plt.xlabel("Fatal Injuries")
plt.ylabel("Make")
plt.show()

# %%
plt.barh(Aviation["Make"].head(100),Aviation["Total.Serious.Injuries"].head(100))
plt.title(" Make Vs Serious injuries")
plt.xlabel("Serious Injuries")
plt.ylabel("Make")
plt.show()

# %%
plt.barh(Aviation["Make"].head(100),Aviation["Total.Uninjured"].head(100))
plt.title(" Make Vs  un injured")
plt.xlabel("Uninjured")
plt.ylabel("Make")
plt.show()

# %% [markdown]
# <h3>Scatter Plot of the number of Engineers and the injuries</h3>

# %%
sns.scatterplot(x='Number.of.Engines', y='Total.Uninjured', data=Aviation,hue="Weather.Condition")
plt.title("correlationship btw Number of Engeerns and unijured passengers")
plt.show()

# %% [markdown]
# <h3>Bar Graph Total Fatal Injuries by Number of Engines</h3>

# %%
# Group data by Number of Engines and calculate total fatal injuries for each
engines_vs_fatal = Aviation.groupby('Total.Fatal.Injuries')['Total.Fatal.Injuries'].count().reset_index(name='Count')
engines_vs_fatal = Aviation.groupby('Number.of.Engines')['Total.Fatal.Injuries'].sum().reset_index()

# Plot bar chart
plt.figure(figsize=(10, 5))
sns.barplot(data=engines_vs_fatal, x='Number.of.Engines', y='Total.Fatal.Injuries', palette='Blues_d')

plt.title("Total Fatal Injuries by Number of Engines")
plt.xlabel("Number of Engines")
plt.ylabel("Total Fatal Injuries")
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# <h3>Our assuption is that aircraft with 4 engines have less incidence of  accidents more than the others having less </h3>

# %% [markdown]
# <h3><b>Correlationship Between number of Engines, Fatal Injuries and the weather conditions</b></h3>

# %%
sns.scatterplot(x='Number.of.Engines', y='Total.Serious.Injuries', data=Aviation,hue="Weather.Condition")
plt.title("correltionship btw Number of Engeerns and Serious injuries")
plt.show()

# %% [markdown]
# <h3><i>from our assuption we are able to see clearly how aircraft with one one engine have more accidents even in normal weather conditions </i></h3>

# %% [markdown]
# <h3>Trend of Fatal Injuries Over Time(Per year)</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert Date column to datetime (if it's not already)
Aviation['Date_time'] = pd.to_datetime(Aviation['Date_time'])

# Group by year and calculate total fatal injuries
Aviation['Year'] = Aviation['Date_time'].dt.year
yearly_fatalities = Aviation.groupby('Year')['Total.Fatal.Injuries'].sum().reset_index()


# Convert Date column to datetime (if it's not already)
Aviation['Date_time'] = pd.to_datetime(Aviation['Date_time'])

# Group by year and calculate total fatal injuries
Aviation['Year'] = Aviation['Date_time'].dt.year
yearly_fatalities = Aviation.groupby('Year')['Total.Fatal.Injuries'].sum().reset_index()

# Plot
plt.figure(figsize=(8, 5))
sns.lineplot(data=yearly_fatalities, x='Year', y='Total.Fatal.Injuries', marker='o', color='red')

plt.title('Total Fatal Injuries per Year')
plt.xlabel('Year')
plt.ylabel('Fatal Injuries')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\JOHN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\JOHN\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h3>We need to Show the kind of Aircraft Make in market from the years upto 2023.<br>You need to chech at the Best model trending in the market </h3>

# %%
make_year_counts = Aviation.groupby(['Year', 'Make']).size().unstack(fill_value=0)

# Step 2: (Optional) Limit to top 5 makes
top_makes = Aviation['Make'].value_counts().head(5).index
make_year_counts = make_year_counts[top_makes]

# Step 3: Plot
make_year_counts.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='Set2')

plt.title('Aircraft Make Reports Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Reports')
plt.legend(title='Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Histograms of the Total Fatal injuries per year</h3>

# %%
# Step 1: Ensure Date_time is datetime format
Aviation['Date_time'] = pd.to_datetime(Aviation['Date_time'], errors='coerce')

# Step 2: Extract year
Aviation['Year'] = Aviation['Date_time'].dt.year

# Step 3: Group by year and sum fatal injuries
injuries_by_year = Aviation.groupby('Year')['Total.Fatal.Injuries'].sum().reset_index()

# Step 4: Plot histogram
plt.figure(figsize=(10, 6))
sns.barplot(data=injuries_by_year, x='Year', y='Total.Fatal.Injuries', color='crimson')

plt.title("Total Fatal Injuries per Year")
plt.xlabel("Year")
plt.ylabel("Total Fatal Injuries")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3><b>Identy the type of flight use with the flight purpose</b> </h3>

# %%
#we are interested to know the type of flight purpose and the type of aircraft used
engines_by_purpose = Aviation.groupby("Purpose.of.flight")["Number.of.Engines"].mean().sort_values()

# Plotting
plt.figure(figsize=(12, 6))
engines_by_purpose.plot(kind='barh', color='skyblue')

plt.title('Average Number of Engines by Flight Purpose')
plt.xlabel('Average Number of Engines')
plt.ylabel('Purpose of Flight')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style={color="blue"}><i>From our analysis we are able to see that the aircraft with 2 engines was used most in the exercutive/coperative flights </i></h3>

# %% [markdown]
# <h3>Lets see which aircraft with the number of engines was highly repaired in terms of Damage</h3>

# %%
damage_engine_counts = Aviation.groupby(['Number.of.Engines', 'Aircraft.damage']).size().unstack(fill_value=0)

damage_engine_counts.plot(kind='bar', figsize=(12, 6), colormap='Set2')

plt.title('Aircraft Damage by Number of Engines')
plt.xlabel('Number of Engines')
plt.ylabel('Number of Incidents')
plt.legend(title='Aircraft Damage')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Number of Flights per Year by Aircraft Make</h3>

# %%
#Aviation.info()
make_year_counts = Aviation.groupby(['Year', 'Make']).size().unstack(fill_value=0)

# Step 2: Select Top 5 Most Frequent Makes (optional for clarity)
top_makes = Aviation['Make'].value_counts().head(5).index
make_year_counts = make_year_counts[top_makes]

# Step 3: Plot as stacked bar chart
make_year_counts.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='tab10')

plt.title('Number of Flights per Year by Aircraft Make')
plt.xlabel('Year')
plt.ylabel('Number of Flights / Reports')
plt.legend(title='Aircraft Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Save the data into excel format for Dash boarding</h3>

# %%
#Aviation.to_excel('cleaned_aircraft_data.xlsx', index=False)

# %%
Aviation.info()
